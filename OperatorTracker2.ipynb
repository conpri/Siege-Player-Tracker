# %%
from ultralytics import YOLO

testModel = YOLO("content/train_copy/weights/best.pt")

# %%
preds = testModel.predict("Siege Pictures/VidTest (1).png")
# Out:
# image 1/1 C:\Users\conpr.CONNORSPC\Documents\Siege\Siege Pictures\VidTest (1).png: 384x640 1 Operator, 23.2ms
# Speed: 1.2ms preprocess, 23.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
for result in preds:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
